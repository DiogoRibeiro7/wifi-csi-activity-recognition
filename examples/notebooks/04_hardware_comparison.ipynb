# %% [markdown]
# # Hardware Comparison
# Compare Intel 5300 and ESP32 drivers.

# %%
from wifi_activity_recognition.hardware import ESP32Reader, Intel5300Reader

intel = Intel5300Reader(...)
esp = ESP32Reader(...)

print("Intel sample:", intel.read_packet())
print("ESP32 sample:", esp.read_packet())
